# %%
import pyspark
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("example").getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/08/08 06:14:44 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
df = spark.createDataFrame([(14, "Tom"), (23, "Alice"), (16, "Bob")], ["age", "name"])
df.explain()
df = df.agg({"age": "max"})
# Out:
# == Physical Plan ==
# *(1) Scan ExistingRDD[age#2L,name#3]

# %%
print("---- simple mode ----")
df.explain(mode="simple")
print("---- extended mode ----")
df.explain(mode="extended")
print("---- codegen mode ----")
df.explain(mode="codegen")
print("---- cost mode ----")
df.explain(mode="cost")
# Out:
# ---- simple mode ----
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- HashAggregate(keys=[], functions=[max(age#2L)])
#    +- Exchange SinglePartition, ENSURE_REQUIREMENTS, [plan_id=23]
#       +- HashAggregate(keys=[], functions=[partial_max(age#2L)])
#          +- Project [age#2L]
#             +- Scan ExistingRDD[age#2L,name#3]
#
#
# ---- extended mode ----
# == Parsed Logical Plan ==
# 'Aggregate [unresolvedalias('max(age#2L))]
# +- LogicalRDD [age#2L, name#3], false
#
# == Analyzed Logical Plan ==
# max(age): bigint
# Aggregate [max(age#2L) AS max(age)#7L]
# +- LogicalRDD [age#2L, name#3], false
#
# == Optimized Logical Plan ==
# Aggregate [max(age#2L) AS max(age)#7L]
# +- Project [age#2L]
#    +- LogicalRDD [age#2L, name#3], false
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- HashAggregate(keys=[], functions=[max(age#2L)], output=[max(age)#7L])
#    +- Exchange SinglePartition, ENSURE_REQUIREMENTS, [plan_id=23]
#       +- HashAggregate(keys=[], functions=[partial_max(age#2L)], output=[max#9L])
#          +- Project [age#2L]
#             +- Scan ExistingRDD[age#2L,name#3]
#
# ---- codegen mode ----
# Found 0 WholeStageCodegen subtrees.
#
# ---- cost mode ----
# == Optimized Logical Plan ==
# Aggregate [max(age#2L) AS max(age)#7L], Statistics(sizeInBytes=16.0 B, rowCount=1)
# +- Project [age#2L], Statistics(sizeInBytes=3.6 EiB)
#    +- LogicalRDD [age#2L, name#3], false, Statistics(sizeInBytes=8.0 EiB)
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- HashAggregate(keys=[], functions=[max(age#2L)], output=[max(age)#7L])
#    +- Exchange SinglePartition, ENSURE_REQUIREMENTS, [plan_id=23]
#       +- HashAggregate(keys=[], functions=[partial_max(age#2L)], output=[max#9L])
#          +- Project [age#2L]
#             +- Scan ExistingRDD[age#2L,name#3]

# %%
df.show()
df.take(1)
# Out:
# +--------+
# |max(age)|
# +--------+
# |      23|
# +--------+
# [Row(max(age)=23)]

# %%
print("---- simple mode ----")
df.explain(mode="simple")
print("---- extended mode ----")
df.explain(mode="extended")
print("---- codegen mode ----")
df.explain(mode="codegen")
print("---- cost mode ----")
df.explain(mode="cost")
# Out:
# ---- simple mode ----
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- HashAggregate(keys=[], functions=[max(age#2L)])
#    +- Exchange SinglePartition, ENSURE_REQUIREMENTS, [plan_id=23]
#       +- HashAggregate(keys=[], functions=[partial_max(age#2L)])
#          +- Project [age#2L]
#             +- Scan ExistingRDD[age#2L,name#3]
#
#
# ---- extended mode ----
# == Parsed Logical Plan ==
# 'Aggregate [unresolvedalias('max(age#2L))]
# +- LogicalRDD [age#2L, name#3], false
#
# == Analyzed Logical Plan ==
# max(age): bigint
# Aggregate [max(age#2L) AS max(age)#7L]
# +- LogicalRDD [age#2L, name#3], false
#
# == Optimized Logical Plan ==
# Aggregate [max(age#2L) AS max(age)#7L]
# +- Project [age#2L]
#    +- LogicalRDD [age#2L, name#3], false
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- HashAggregate(keys=[], functions=[max(age#2L)], output=[max(age)#7L])
#    +- Exchange SinglePartition, ENSURE_REQUIREMENTS, [plan_id=23]
#       +- HashAggregate(keys=[], functions=[partial_max(age#2L)], output=[max#9L])
#          +- Project [age#2L]
#             +- Scan ExistingRDD[age#2L,name#3]
#
# ---- codegen mode ----
# Found 0 WholeStageCodegen subtrees.
#
# ---- cost mode ----
# == Optimized Logical Plan ==
# Aggregate [max(age#2L) AS max(age)#7L], Statistics(sizeInBytes=16.0 B, rowCount=1)
# +- Project [age#2L], Statistics(sizeInBytes=3.6 EiB)
#    +- LogicalRDD [age#2L, name#3], false, Statistics(sizeInBytes=8.0 EiB)
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- HashAggregate(keys=[], functions=[max(age#2L)], output=[max(age)#7L])
#    +- Exchange SinglePartition, ENSURE_REQUIREMENTS, [plan_id=23]
#       +- HashAggregate(keys=[], functions=[partial_max(age#2L)], output=[max#9L])
#          +- Project [age#2L]
#             +- Scan ExistingRDD[age#2L,name#3]
